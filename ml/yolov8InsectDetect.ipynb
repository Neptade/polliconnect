# %%
from ultralytics import YOLO

# %% [markdown]
# # train

# %%
model = YOLO('../models/yolov8n.pt')

# %%
# model.train(data='../datasets/Insect_Detect_detection.v5-insect_detect_raw_4k.yolov8/data.yaml', epochs=10, device=0)
model.train(data='../datasets/ArTaxOrYolo/data.yaml', epochs=10, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.38 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.11  Python-3.11.5 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %% [markdown]
# # test

# %%
model = YOLO('../runs/detect/train10eArTaxOr/weights/best.pt')

# %%
results = model('../datasets/Insect_Detect_detection.v5-insect_detect_raw_4k.yolov8/test/images')
# Out:
# image 1/133 c:\Users\loic\OneDrive\Documents\school\M1\semester2\polliConnect\ml\..\datasets\Insect_Detect_detection.v5-insect_detect_raw_4k.yolov8\test\images\20220905_17-01-33-674278_raw_jpg.rf.e60109e7b8efdc4b04ac996398963eb1.jpg: 384x640 1 Coleoptera, 57.5ms
# image 2/133 c:\Users\loic\OneDrive\Documents\school\M1\semester2\polliConnect\ml\..\datasets\Insect_Detect_detection.v5-insect_detect_raw_4k.yolov8\test\images\20220905_17-02-30-115962_raw_jpg.rf.19a8c620d3471e04abf472eec48a2577.jpg: 384x640 (no detections), 4.0ms
# image 3/133 c:\Users\loic\OneDrive\Documents\school\M1\semester2\polliConnect\ml\..\datasets\Insect_Detect_detection.v5-insect_detect_raw_4k.yolov8\test\images\20220906_09-01-30-955770_raw_jpg.rf.86dfd714c9c3194a270935307140f776.jpg: 384x640 (no detections), 4.0ms
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import matplotlib.pyplot as plt
#       3 # Assuming 'results' is the variable containing the prediction results
#       4 # Extract the statistics from the results
# ----> 5 statistics = results['statistics']
#       7 # Plot the statistics
#       8 plt.figure(figsize=(10, 6))
#
# NameError: name 'results' is not defined
